# %% [markdown]
# # FIFA DATASET EXPLORATORY DATA ANALYSIS
# THE GOAL OF THIS ANALYSIS IS TO ANSWER THESE QUESTIONS GENERATED BY AI ON THE FIFA 23 DATASET AND ALSO TO EXPLORE THE DATASET.

# %% [markdown]
# 1. Who is the highest rated male player in FIFA 23, and what are his attributes?
# 2. What is the distribution of player positions for male players in FIFA 23?
# 3. Which national teams have the most players represented in FIFA 23?
# 4. What is the average age of male players in FIFA 23?
# 5. What is the correlation between a player's overall rating and their individual attributes.
# 6. What are the most common countries for male players in FIFA 23?
# 7. Which countries have the highest overall ratings for their male players in FIFA 23?
# 8. Which male player has the highest dribbling rating in FIFA 23?
# 9. How many male players have a rating of 90 or higher in FIFA 23?
# 10. What is the distribution of the height and weight of male players in FIFA 23?
# 11. Which club has the highest average overall rating for their male players in FIFA 23?
# 12. What is the average wage for male players in FIFA 23?
# 13. Which male player has the highest physical rating in FIFA 23?
# 14. Which male player has the highest shooting rating in FIFA 23?
# 15. What is the average rating for male players in the top five Countries in FIFA 23?
# 16. Which male player has the highest passing rating in FIFA 23?
# 17. How many male players have a rating of 80 or higher for their physical attribute in FIFA 23?
# 18. Which country has the highest number of players rated 80 or higher in FIFA 23?
# 19. What is the average overall rating of male players in FIFA 23?
# 20. Which male player has the highest pace rating in FIFA 23?
# 21. How many male players have a rating of 90 or greater

# %% [markdown]
# # IMPORT NECESSARY LIBRARIES

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA EXPLORATION

# %%
cd "C:\\Users\\OLANIYI OGUNDELE"
# Out:
# C:\Users\OLANIYI OGUNDELE

# %%
cd "C:\Users\OLANIYI OGUNDELE\Desktop\DATA SCIENCE FILES\NEW FIFA DATASET"
# Out:
# C:\Users\OLANIYI OGUNDELE\Desktop\DATA SCIENCE FILES\NEW FIFA DATASET

# %%
#Import the csv file
data = pd.read_csv('FIFA22_official_data.csv')

# %%
data.shape
# Out:
# (16710, 65)

# %%
data.head()
# Out:
#        ID             Name  Age  \
# 0  212198  Bruno Fernandes   26
# 1  209658      L. Goretzka   26
# 2  176580        L. Suárez   34
# 3  192985     K. De Bruyne   30
# 4  224334         M. Acuña   29
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1  https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2  https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/pt.png       88         89
# 1  https://cdn.sofifa.com/flags/de.png       87         88
# 2  https://cdn.sofifa.com/flags/uy.png       88         88
# 3  https://cdn.sofifa.com/flags/be.png       91         91
# 4  https://cdn.sofifa.com/flags/ar.png       84         84
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16710 entries, 0 to 16709
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        16710 non-null  int64
#  1   Name                      16710 non-null  object
#  2   Age                       16710 non-null  int64
#  3   Photo                     16710 non-null  object
#  4   Nationality               16710 non-null  object
#  5   Flag                      16710 non-null  object
#  6   Overall                   16710 non-null  int64
#  7   Potential                 16710 non-null  int64
#  8   Club                      16446 non-null  object
#  9   Club Logo                 16710 non-null  object
#  10  Value                     16710 non-null  object
#  11  Wage                      16710 non-null  object
#  12  Special                   16710 non-null  int64
# ...

# %%
data.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   16710.000000  16710.000000  16710.000000  16710.000000  16710.000000
# mean   220560.467923     25.727409     67.646320     72.572292   1652.497307
# std     38496.607959      5.048910      6.457695      5.688085    257.271696
# min        27.000000     16.000000     28.000000     38.000000    571.000000
# 25%    203891.250000     22.000000     63.000000     69.000000   1525.000000
# 50%    229253.000000     25.000000     68.000000     72.000000   1687.000000
# 75%    245368.750000     29.000000     72.000000     76.000000   1826.000000
# max    264704.000000     54.000000     93.000000     95.000000   2341.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              16710.000000  16710.000000  16710.000000   16684.000000
# mean                   1.169958      3.008199      2.475464      20.458643
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'Release Clause',
# ...

# %% [markdown]
# # FEATURE SELECTION

# %%
#Select columns relevant to the analysis
attributes = data[['ID','Name','Age','Nationality','Overall','Club','Wage','Best Position','Height','Weight','Crossing','Finishing','HeadingAccuracy','ShortPassing','LongPassing','Dribbling','Acceleration','SprintSpeed','Agility','Reactions','Balance','ShotPower','Stamina','Strength','LongShots','Vision','StandingTackle','SlidingTackle']]

# %%
attributes.shape
# Out:
# (16710, 28)

# %%
attributes.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Club', 'Wage',
#        'Best Position', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'LongPassing', 'Dribbling',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Stamina', 'Strength', 'LongShots', 'Vision',
#        'StandingTackle', 'SlidingTackle'],
#       dtype='object')

# %% [markdown]
# # DEALING WITH MISSING VALUES

# %%
#Count number of null values in each column
attributes.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Nationality          0
# Overall              0
# Club               264
# Wage                 0
# Best Position        0
# Height               0
# Weight               0
# Crossing             0
# Finishing            0
# HeadingAccuracy      0
# ShortPassing         0
# LongPassing          0
# Dribbling            0
# Acceleration         0
# SprintSpeed          0
# Agility             37
# Reactions            0
# Balance             37
# ShotPower            0
# Stamina              0
# Strength             0
# LongShots            0
# Vision              37
# StandingTackle       0
# SlidingTackle       37
# dtype: int64

# %%
#Drop all rows with null values
attributes.dropna(axis = 0,inplace = True)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\2205156532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes.dropna(axis = 0,inplace = True)

# %%
attributes.isnull().sum()
# Out:
# ID                 0
# Name               0
# Age                0
# Nationality        0
# Overall            0
# Club               0
# Wage               0
# Best Position      0
# Height             0
# Weight             0
# Crossing           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# LongPassing        0
# Dribbling          0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Stamina            0
# Strength           0
# LongShots          0
# Vision             0
# StandingTackle     0
# SlidingTackle      0
# dtype: int64

# %% [markdown]
# # VISUALIZING THE DISTRIBUTION OF VALUES ACROSS, COUNTRIES,CLUBS e.t.c

# %%
country_count = data['Nationality'].value_counts().head(20)

# %%
country_count.plot(kind = 'bar',color ='purple')
plt.title('Top 20 most represented countries in FIFA 23', y=1.12)
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
overall_disribution = data['Overall'].value_counts()

# %%
plt.hist(data["Overall"], bins = 6,color='purple')

# set x/y labels and plot title
plt.xlabel("Rating")
plt.ylabel("count")
plt.title("Distribution by Overall rating")
# Out:
# Text(0.5, 1.0, 'Distribution by Overall rating')

# %%
club_distribution = data['Club'].value_counts().head(20)

# %%
club_distribution.plot(kind = 'bar',color ='purple')
plt.title('Top 20 most represented clubs in FIFA 23', y=1.12)
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
#remove the euro sign and letter K in wages column 
attributes['Wage'] = attributes['Wage'].str.replace('\u20AC', '')
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\3922424173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Wage'] = attributes['Wage'].str.replace('\u20AC', '')

# %%
attributes['Wage'] = attributes['Wage'].str.replace('K', '')
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\2543984114.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Wage'] = attributes['Wage'].str.replace('K', '')

# %%
attributes['Wage'] = attributes['Wage'].astype(float)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\1884458817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Wage'] = attributes['Wage'].astype(float)

# %%
plt.hist(attributes['Wage'], bins = 5,color='purple')

# set x/y labels and plot title
plt.xlabel("Wage")
plt.ylabel("count")
plt.title("Distribution by Wage")
# Out:
# Text(0.5, 1.0, 'Distribution by Wage')

# %%
dist_position = data['Best Position'].value_counts()

# %%
import matplotlib.pyplot as plt
dist_position.plot(kind = 'bar',color ='purple')
plt.title('Distribution of player positions for male players in FIFA 23', y=1.12)
plt.xlabel("Position")
plt.ylabel("Count")
plt.show()

# %%
#renaming the Best Position column
attributes.rename(columns={'Best Position':'Position'},inplace=True)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\1434176000.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes.rename(columns={'Best Position':'Position'},inplace=True)

# %%
#since CF and ST refer to the same position we replace CF with ST.
attributes['Position'].replace('CF','ST',inplace=True)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\1562466067.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Position'].replace('CF','ST',inplace=True)

# %%
#since LWB and LB refer to the same position we replace LWB with LB.
attributes['Position'].replace('LWB','LB',inplace=True)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\906869415.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Position'].replace('LWB','LB',inplace=True)

# %%
#since RWB and RB refer to the same position we replace RWB with RB.
attributes['Position'].replace('RWB','RB',inplace=True)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\929618808.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Position'].replace('RWB','RB',inplace=True)

# %%
dist_position = attributes['Position'].value_counts()

# %%
dist_position.plot(kind = 'bar',color ='purple')
plt.title('Distribution of male player positions  in FIFA 23', y=1.12)
plt.xlabel("Position")
plt.ylabel("Count")
plt.show()

# %%
attributes['Height'] = attributes['Height'].str.replace('cm', '')
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\3339281123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Height'] = attributes['Height'].str.replace('cm', '')

# %%
attributes['Height'] = attributes['Height'].astype(float)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\563201180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Height'] = attributes['Height'].astype(float)

# %%
# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(attributes["Height"], bins = 6,color='purple')

# set x/y labels and plot title
plt.pyplot.xlabel("Height")
plt.pyplot.ylabel("count")
plt.pyplot.title("Distribution by height")
# Out:
# Text(0.5, 1.0, 'Distribution by height')

# %%
attributes['Weight'] = attributes['Weight'].str.replace('kg', '')
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\1731993513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Weight'] = attributes['Weight'].str.replace('kg', '')

# %%
attributes['Weight'] = attributes['Weight'].astype(float)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\4190763670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Weight'] = attributes['Weight'].astype(float)

# %%
plt.pyplot.hist(attributes["Weight"], bins = 6,color = 'purple')

# set x/y labels and plot title
plt.pyplot.xlabel("Weight")
plt.pyplot.ylabel("count")
plt.pyplot.title("Distribution by weight")
# Out:
# Text(0.5, 1.0, 'Distribution by weight')

# %%
attributes.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Club', 'Wage',
#        'Position', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'LongPassing', 'Dribbling',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Stamina', 'Strength', 'LongShots', 'Vision',
#        'StandingTackle', 'SlidingTackle'],
#       dtype='object')

# %% [markdown]
# # CONCATENATE THE ALIKE COLUMNS INTO A SINGLE COLUMN e.g shortpassing and longpassing as passing

# %%
attributes['Passing']  = attributes[['LongPassing','ShortPassing']].mean(axis=1)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\241217076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Passing']  = attributes[['LongPassing','ShortPassing']].mean(axis=1)

# %%
attributes['Pace'] = attributes[['Acceleration','SprintSpeed']].mean(axis=1)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\205793526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Pace'] = attributes[['Acceleration','SprintSpeed']].mean(axis=1)

# %%
attributes['Physicality'] = attributes[['Stamina','Strength','Agility']].mean(axis=1)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\1238897081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Physicality'] = attributes[['Stamina','Strength','Agility']].mean(axis=1)

# %%
attributes['Tackling'] = attributes[['StandingTackle','SlidingTackle']].mean(axis=1)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\979446685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Tackling'] = attributes[['StandingTackle','SlidingTackle']].mean(axis=1)

# %%
attributes['Shooting'] = attributes[['LongShots','ShotPower']].mean(axis=1)
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\2284718969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes['Shooting'] = attributes[['LongShots','ShotPower']].mean(axis=1)

# %% [markdown]
# # DROP THE FORMER COLUMNS

# %%
attributes = attributes.drop(['Acceleration','SprintSpeed','Stamina','Strength','Agility','StandingTackle','SlidingTackle','LongShots','ShotPower','LongPassing','ShortPassing'],axis = 1)

# %%
attributes.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Club', 'Wage',
#        'Position', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'Dribbling', 'Reactions', 'Balance', 'Vision',
#        'Passing', 'Pace', 'Physicality', 'Tackling', 'Shooting'],
#       dtype='object')

# %%
attributes.shape
# Out:
# (16416, 22)

# %% [markdown]
# # SHOW CORRELATION BETWEEN THE WAGES, AGE, OVERALL, NATIONALITY, REACTIONS, PACE, DRIBBLING ETC

# %%
correlation_attributes=attributes[['Age','Overall','Wage','Nationality','Reactions','Pace','Dribbling']]

# %%
sns.pairplot(correlation_attributes, kind='reg')

# %% [markdown]
# # CORRELATION HEATMAP OF THE DATA

# %%
fig, ax = plt.subplots(figsize=(10, 8))
corr = attributes.corr()
sns.heatmap(corr, cmap='plasma', annot=True, annot_kws={"size": 6},ax=ax)
plt.show()
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\1313912137.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = attributes.corr()

# %% [markdown]
# # DATA ANALYSIS QUESTIONS

# %% [markdown]
# 1. Who is the highest rated male player in FIFA 23, and what are his attributes?

# %%
max_rating = attributes.loc[attributes['Overall'].idxmax()]
print(max_rating)
# Out:
# ID                              158023
# Name                          L. Messi
# Age                                 34
# Nationality                  Argentina
# Overall                             93
# Club               Paris Saint-Germain
# Wage                             320.0
# Position                            RW
# Height                           170.0
# Weight                            72.0
# Crossing                          85.0
# Finishing                         95.0
# HeadingAccuracy                   70.0
# Dribbling                         96.0
# Reactions                         94.0
# Balance                           95.0
# Vision                            95.0
# Passing                           91.0
# Pace                              85.5
# Physicality                  77.333333
# Tackling                          29.5
# Shooting                          90.0
# Name: 29, dtype: object

# %% [markdown]
# 2. What is the average age of male players in FIFA 23?

# %%
average_age = attributes['Age'].mean()
print(average_age)
# Out:
# 25.671722709551656

# %% [markdown]
# 3. What is the correlation between a player's overall rating and their individual attributes.

# %%
attributes.corr()['Overall'].sort_values().to_frame()
# Out:
# C:\Users\OLANIYI OGUNDELE\AppData\Local\Temp\ipykernel_1932\825450764.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   attributes.corr()['Overall'].sort_values().to_frame()
#                   Overall
# ID              -0.381950
# Wage            -0.288519
# Height           0.031162
# Balance          0.086525
# Pace             0.122273
# Weight           0.141259
# Tackling         0.221305
# Finishing        0.287970
# HeadingAccuracy  0.300904
# Dribbling        0.329274
# Crossing         0.358106
# Physicality      0.406342
# Shooting         0.445018
# Age              0.472837
# Passing          0.494572
# Vision           0.496446
# Reactions        0.870949
# Overall          1.000000

# %% [markdown]
# 4. Which countries have the highest overall ratings for their male players in FIFA 23?

# %%
grp = attributes[['Overall','Nationality']]
cont_rating =grp.groupby(['Nationality'], as_index = False).mean()
cont_rating
# Out:
#      Nationality    Overall
# 0    Afghanistan  65.000000
# 1        Albania  67.583333
# 2        Algeria  71.517241
# 3        Andorra  64.000000
# 4         Angola  69.050000
# ..           ...        ...
# 163    Venezuela  66.548780
# 164      Vietnam  63.000000
# 165        Wales  63.898089
# 166       Zambia  67.800000
# 167     Zimbabwe  67.500000
#
# [168 rows x 2 columns]

# %%
top_10 = cont_rating.loc[cont_rating['Overall'].nlargest(10).index]

# %%
top_10
# Out:
#         Nationality    Overall
# 46            Egypt  74.181818
# 151        Tanzania  74.000000
# 108      Mozambique  72.750000
# 20           Brazil  72.366667
# 92            Libya  72.250000
# 53             Fiji  72.000000
# 109         Namibia  72.000000
# 41   Czech Republic  71.632653
# 2           Algeria  71.517241
# 158         Ukraine  71.415385

# %% [markdown]
# 5.  Which player has the highest dribbling rating in FIFA 23?

# %%
top_dribbler = attributes.loc[attributes['Dribbling'].idxmax()]
print(top_dribbler)
# Out:
# ID                              158023
# Name                          L. Messi
# Age                                 34
# Nationality                  Argentina
# Overall                             93
# Club               Paris Saint-Germain
# Wage                             320.0
# Position                            RW
# Height                           170.0
# Weight                            72.0
# Crossing                          85.0
# Finishing                         95.0
# HeadingAccuracy                   70.0
# Dribbling                         96.0
# Reactions                         94.0
# Balance                           95.0
# Vision                            95.0
# Passing                           91.0
# Pace                              85.5
# Physicality                  77.333333
# Tackling                          29.5
# Shooting                          90.0
# Name: 29, dtype: object

# %% [markdown]
# 6. How many male players have a rating of 90 or higher in FIFA 23?

# %%
over90 = attributes['Dribbling'] >= 90
attributes[over90]
# Out:
#           ID              Name  Age    Nationality  Overall  \
# 19    193082       J. Cuadrado   33       Colombia       83
# 29    158023          L. Messi   34      Argentina       93
# 34    209331          M. Salah   29          Egypt       89
# 42    199556       M. Verratti   28          Italy       87
# 44    189509            Thiago   30          Spain       86
# 55    208722           S. Mané   29        Senegal       89
# 64    190871         Neymar Jr   29         Brazil       91
# 82    231747         K. Mbappé   22         France       91
# 156   211110         P. Dybala   27      Argentina       87
# 170   218667    Bernardo Silva   26       Portugal       86
# 443   197781              Isco   29          Spain       82
# 606   204485         R. Mahrez   30        Algeria       86
# 625   184267     19 Y. Brahimi   28        Algeria       85
# 691   198219        L. Insigne   30          Italy       86
# 704   190483  21 Douglas Costa   29         Brazil       80
# ...

# %% [markdown]
# 7. Which club has the highest average overall rating for their male players in FIFA 23?

# %%
grp1 = attributes[['Overall','Club']]
club_rating =grp1.groupby(['Club'], as_index = False).mean()
club_rating
# Out:
#                           Club    Overall
# 0        1. FC Heidenheim 1846  66.807692
# 1         1. FC Kaiserslautern  63.916667
# 2                   1. FC Köln  69.142857
# 3              1. FC Magdeburg  62.833333
# 4               1. FC Nürnberg  66.703704
# ..                         ...        ...
# 857              Östersunds FK  62.687500
# 858     İstanbul Başakşehir FK  71.741935
# 859  İttifak Holding Konyaspor  69.250000
# 860                   ŁKS Łódź  50.000000
# 861              Śląsk Wrocław  63.666667
#
# [862 rows x 2 columns]

# %%
top_10 = club_rating.loc[club_rating['Overall'].nlargest(10).index]

# %%
top_10
# Out:
#                      Club    Overall
# 304  FC Anzhi Makhachkala  79.000000
# 462              Juventus  78.625000
# 310     FC Bayern München  78.593750
# 587   Paris Saint-Germain  78.585366
# 521     Manchester United  78.125000
# 327          FC Krasnodar  78.000000
# 85     Atlético de Madrid  77.405405
# 546                Napoli  77.222222
# 680            SL Benfica  76.888889
# 307          FC Barcelona  76.871795

# %% [markdown]
# 8.  What is the average wage for male players in FIFA 23?

# %%
average_wage = attributes['Wage'].mean()
average_wage
# Out:
# 91.71576510721248

# %% [markdown]
# 9. Which male player has the highest physical rating in FIFA 23?

# %%
max_physical = attributes.loc[attributes['Physicality'].idxmax()]
print(max_physical)
# Out:
# ID                                  216189
# Name                                  Capa
# Age                                     29
# Nationality                          Spain
# Overall                                 80
# Club               Athletic Club de Bilbao
# Wage                                  32.0
# Position                                RB
# Height                               175.0
# Weight                                75.0
# Crossing                              81.0
# Finishing                             56.0
# HeadingAccuracy                       60.0
# Dribbling                             76.0
# Reactions                             74.0
# Balance                               86.0
# Vision                                75.0
# Passing                               73.5
# Pace                                  82.0
# Physicality                      86.666667
# Tackling                              77.0
# Shooting                              75.0
# ...

# %% [markdown]
# 10. Which male player has the highest shooting rating in FIFA 23?

# %%
max_shooting = attributes.loc[attributes['Shooting'].idxmax()]
print(max_shooting)
# Out:
# ID                             20801
# Name               Cristiano Ronaldo
# Age                               36
# Nationality                 Portugal
# Overall                           91
# Club               Manchester United
# Wage                           270.0
# Position                          ST
# Height                         187.0
# Weight                          83.0
# Crossing                        87.0
# Finishing                       95.0
# HeadingAccuracy                 90.0
# Dribbling                       88.0
# Reactions                       94.0
# Balance                         74.0
# Vision                          76.0
# Passing                         78.5
# Pace                            86.5
# Physicality                     80.0
# Tackling                        28.0
# Shooting                        93.5
# Name: 36, dtype: object

# %% [markdown]
# 11. Which male player has the highest passing rating in FIFA 23?

# %%
max_passing = attributes.loc[attributes['Passing'].idxmax()]
print(max_passing)
# Out:
# ID                          192985
# Name                  K. De Bruyne
# Age                             30
# Nationality                Belgium
# Overall                         91
# Club               Manchester City
# Wage                         350.0
# Position                        CM
# Height                       181.0
# Weight                        70.0
# Crossing                      94.0
# Finishing                     82.0
# HeadingAccuracy               55.0
# Dribbling                     88.0
# Reactions                     91.0
# Balance                       78.0
# Vision                        94.0
# Passing                       93.5
# Pace                          76.0
# Physicality              80.666667
# Tackling                      59.0
# Shooting                      91.0
# Name: 3, dtype: object

# %% [markdown]
# 12.How many male players have a rating of 80 or higher for their physical attribute in FIFA 23?

# %%
over80 = attributes['Physicality'] >= 80
attributes[over80].count()
# Out:
# ID                 281
# Name               281
# Age                281
# Nationality        281
# Overall            281
# Club               281
# Wage               281
# Position           281
# Height             281
# Weight             281
# Crossing           281
# Finishing          281
# HeadingAccuracy    281
# Dribbling          281
# Reactions          281
# Balance            281
# Vision             281
# Passing            281
# Pace               281
# Physicality        281
# Tackling           281
# Shooting           281
# dtype: int64

# %% [markdown]
# 13. Which country has the highest number of players rated 80 or higher in FIFA 23?

# %%
cont_over80s = attributes[attributes['Overall'] > 80].groupby('Nationality').size()

# %%
cont_over80s.idxmax()
# Out:
# 'Spain'

# %% [markdown]
# 14. What is the average overall rating of male players in FIFA 23?

# %%
average_rating = attributes['Overall'].mean()
print(average_rating)
# Out:
# 67.60550682261209

# %% [markdown]
# 15.  Which male player has the highest pace rating in FIFA 23?

# %%
max_pace = attributes.loc[attributes['Pace'].idxmax()]
print(max_pace)
# Out:
# ID                              231747
# Name                         K. Mbappé
# Age                                 22
# Nationality                     France
# Overall                             91
# Club               Paris Saint-Germain
# Wage                             230.0
# Position                            ST
# Height                           182.0
# Weight                            73.0
# Crossing                          78.0
# Finishing                         93.0
# HeadingAccuracy                   72.0
# Dribbling                         93.0
# Reactions                         93.0
# Balance                           83.0
# Vision                            82.0
# Passing                           78.0
# Pace                              97.0
# Physicality                  85.666667
# Tackling                          33.0
# Shooting                          84.0
# Name: 82, dtype: object

# %% [markdown]
# 16. How many male players have a rating of 90 or greater

# %%
rating90 = attributes['Overall'] >= 90
attributes[rating90].count()
# Out:
# ID                 11
# Name               11
# Age                11
# Nationality        11
# Overall            11
# Club               11
# Wage               11
# Position           11
# Height             11
# Weight             11
# Crossing           11
# Finishing          11
# HeadingAccuracy    11
# Dribbling          11
# Reactions          11
# Balance            11
# Vision             11
# Passing            11
# Pace               11
# Physicality        11
# Tackling           11
# Shooting           11
# dtype: int64
